# %% [markdown]
# <a href="https://colab.research.google.com/github/maxrinal/nlp-disaster/blob/master/TP2_CODES/DiCaro_97582/LGBM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Machine Learning**

# %% [markdown]
# ## Importo Librerías

# %%
#! python -m textblob.download_corpora
#!pip install --user -U nltk
#nltk.download('punkt')
#!pip install kaggle
#!pip install catboost
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.18.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (0.16.0)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp36-none-any.whl size=11685 sha256=65cbbd627d463f4a98ac9c67e5f959c934fdf9d7353790781b5de9156eea13e5
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from textblob import TextBlob
from wordcloud import WordCloud
import string,re
import urllib.parse
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize #Tokenizador
from nltk .tokenize.regexp import regexp_tokenize #Tokenizador
import spacy
import keras
import html
import re
import urllib
import warnings
import time
import random

from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.preprocessing import MultiLabelBinarizer #Para encoding binario
from sklearn.preprocessing import LabelBinarizer #Para encoding binario
from sklearn.preprocessing import LabelEncoder #Para encoding binario
from sklearn.preprocessing import OneHotEncoder #Para encoding binario
from sklearn.preprocessing import StandardScaler #Normalización de la matriz
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA
from sklearn.metrics import mean_squared_error 
from sklearn import tree
from sklearn.model_selection import train_test_split #Split set de datos en train y test
from sklearn.metrics import f1_score #Metrica F1_Score
from sklearn.feature_extraction.text import CountVectorizer #Transforma tokens en vectores
from sklearn.neighbors import KNeighborsClassifier

# %%
import lightgbm as lgb
import xgboost as xgb 
from bayes_opt import BayesianOptimization
nltk.download('stopwords') #Descargo Stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

plt.style.use('default') #Haciendo los gráficos más bonitos en matplotlib

sns.set(style = 'whitegrid') #Seteando tipo de grid en sns

pd.options.display.float_format = '{:20,.2f}'.format #Suprimimos la notacion científica en los outputs

warnings.filterwarnings("ignore")

# %%
print('re version', re.__version__)
print('nltk version', nltk.__version__)
print('spacy version', spacy.__version__)
print('keras version', keras.__version__)
# Out:
# re version 2.2.1
# nltk version 3.2.5
# spacy version 2.2.4
# keras version 2.4.3

# %% [markdown]
# ## Importo Datos

# %%
#Importo directo de github los set de datos de la competencia
train_original = pd.read_csv('https://raw.githubusercontent.com/maxrinal/nlp-disaster/master/train.csv', encoding = 'utf-8') 
test_original = pd.read_csv('https://raw.githubusercontent.com/maxrinal/nlp-disaster/master/test.csv', encoding = 'utf-8')

# %%
test_original.head()
# Out:
#    id keyword location                                               text
# 0   0     NaN      NaN                 Just happened a terrible car crash
# 1   2     NaN      NaN  Heard about #earthquake is different cities, s...
# 2   3     NaN      NaN  there is a forest fire at spot pond, geese are...
# 3   9     NaN      NaN           Apocalypse lighting. #Spokane #wildfires
# 4  11     NaN      NaN      Typhoon Soudelor kills 28 in China and Taiwan

# %%
#Concateno el set de test y de train para aplicarle las mismas transformaciones y limpiezas.
train = pd.concat([train_original, test_original])[['id', 'keyword', 'location', 'text', 'target']]

# %%
#Leo el set de Franco. Esto lo hicimos para trabajar todos con el mismo split y para probar mergear ambos modelos de datos
set_train_franco = pd.read_csv('/content/drive/My Drive/OrgaDeDatos/Set_Franco_V1/Copia de FEATURES_train.csv')
set_test_franco = pd.read_csv('/content/drive/My Drive/OrgaDeDatos/Set_Franco_V1/Copia de FEATURES_validation.csv')
set_submit_franco = pd.read_csv('/content/drive/My Drive/OrgaDeDatos/Set_Franco_V1/Copia de FEATURES_test.csv')

# %%
#Concatenos los set de Franco y luego elimino la columna target ya que luego realizare un merge con mi modelo
train_franco = pd.concat([set_train_franco, set_test_franco, set_submit_franco])
train_franco.drop(columns= ['target'], inplace= True)

# %%
print(len(set_train_franco))
print(len(set_test_franco))
print(len(train) == len(train_franco))
# Out:
# 6090
# 1523
# True

# %%
#Mergeo mi modelo con el de Franco
train = train_franco.merge(train, left_on= 'id', right_on= 'id', how= 'left')

# %%
#Creo lista con las columnas del set de franco luego elmino la de id
franco_features = train_franco.columns.tolist()
franco_features.pop(0)
# Out:
# 'id'

# %% [markdown]
# # Limpieza

# %% [markdown]
# ### Funciones

# %%
#Creo lista de caracteres raros para luego eliminarlos
caracteres_extraños = ['\u017E', '\u017D', '\u017C', '\u017B', '\u017A', '\u0179', '\u0178', '\u0177', '\u0176', '\u00FF', '\u00FD', '\u00DD', '\u0175',\
                         '\u0174', '\u0173', '\u0172', '\u0171', '\u0170', '\u016F', '\u016E', '\u016D', '\u016C', '\u016B', '\u016A', '\u0169', '\u0168',\
                         '\u00FC', '\u00FB', '\u00FA', '\u00F9', '\u00DC', '\u00DB', '\u00DA', '\u00D9', '\u0167', '\u0166', '\u0165', '\u0164', '\u0163',\
                         '\u0162', '\u017F', '\u0161', '\u0160', '\u015F', '\u015E', '\u015D', '\u015C', '\u015B', '\u015A', '\u0159', '\u0158', '\u0157',\
                         '\u0156', '\u0155', '\u0154', '\u0151', '\u0150', '\u014F', '\u014E', '\u014D', '\u014C', '\u00F8', '\u00F6', '\u00F5', '\u00F4',\
                         '\u00F3', '\u00F2', '\u00D8', '\u00D6', '\u00D5', '\u00D4', '\u00D3', '\u00D2', '\u014B', '\u014A', '\u0149', '\u0148', '\u0147',\
                         '\u0146', '\u0145', '\u0144', '\u0143', '\u00F1', '\u00D1', '\u0142', '\u0141', '\u0140', '\u013F', '\u013E', '\u013D', '\u013C',\
                         '\u013B', '\u013A', '\u0139', '\u0138', '\u0137', '\u0136', '\u0135', '\u0134', '\u0131', '\u0130', '\u012F', '\u012E', '\u012D',\
                         '\u012C', '\u012B', '\u012A', '\u0129', '\u0128', '\u00EF', '\u00EE', '\u00ED', '\u00EC', '\u00CF', '\u00CE', '\u00CD', '\u00CC',\
                         '\u0127', '\u0126', '\u0125', '\u0124', '\u0123', '\u0122', '\u0121', '\u0120', '\u011F', '\u011E', '\u011D', '\u011C', '\u011B',\
                         '\u011A', '\u0119', '\u0118', '\u0117', '\u0116', '\u0115', '\u0114', '\u0113', '\u0112', '\u00EB', '\u00EA', '\u00E9', '\u00E8',\
                         '\u00CB', '\u00CA', '\u00C9', '\u00C8', '\u0111', '\u0110', '\u010F', '\u010E', '\u00F0', '\u00D0', '\u010D', '\u010C', '\u010B',\
                         '\u010A', '\u0109', '\u0108', '\u0107', '\u0106', '\u00E7', '\u00C7', '\u0105', '\u0104', '\u0103', '\u0102', '\u0101', '\u0100',\
                         '\u00E5', '\u00E4', '\u00E3', '\u00E2', '\u00E1', '\u00E0', '\u00C5', '\u00C4', '\u00C3', '\u00C2', '\u00C0', '\u00C1']

#Mas caracteres raros para eliminar
monosilabos = ['£', '¤', '¨', '«', '¬', '´', '¡']

#Lista de stopwords en ingles
words_to_clean = stopwords.words('english')
words_to_clean.append('') #Agrego a la lista el vacio para eliminar

# %%
#Funcion para remover caracteres
def remuevo_caracteres_de_lista (texto, lista):
  for caracter in lista:
    texto = texto.replace(caracter, ' ')
  return texto

#Función para limpieza del texto
def clean_texto (texto, caracteres_extraños, monosilabos):
  texto = re.compile(r'https?://\S+|www\.\S+').sub(r'',texto) #Removing urls
  texto = html.unescape(texto)
  texto = urllib.parse.unquote(str(texto))
  texto = re.compile(r'<.*?>').sub(r'',texto) #Removing HTML tags
  texto = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags = re.UNICODE).sub(r'', texto)
  texto = texto.translate(str.maketrans('','',string.punctuation))
  texto = texto.lower()
  texto = texto.translate(str.maketrans('','','1234567890'))
  texto = texto.replace('\n', ' ').replace('å', ' ').replace('ê', ' ').replace('û', ' ').replace('[^\w\s]',' ').replace('÷', ' ').replace('ª', ' ')\
             .replace('ì', ' ').replace('¢', ' ').replace('\x89', ' ').replace('\x9d', ' ').replace('ã', ' ').replace('ï', ' ').replace('©', ' ')\
             .replace('ó', ' ').replace('ò', ' ').replace('â', ' ').replace('\x9b', ' ').replace('\x8a', ' ').replace('\x93', ' ').replace('\x8f', ' ')\
             .replace('\x8c', ' ').replace('¼', ' ').replace('¥', ' ').replace('\x92', ' ').replace('·', ' ').replace('\x82', ' ').replace('Û', ' ')\
             .replace('Ó', ' ').replace('Ê', ' ').replace('Ï', ' ')
  texto = remuevo_caracteres_de_lista(texto, caracteres_extraños)
  texto = remuevo_caracteres_de_lista(texto, monosilabos)
  return texto

#Funcion tokenización customizada a partir de regex                        
def custom_tokenize (notes, caracteres_extraños, monosilabos):
  notes = [clean_texto(texto, caracteres_extraños, monosilabos) for texto in notes]
  tokens = regexp_tokenize(' '.join(notes), pattern = '\s+', gaps = True)
  return tokens

#Funcion para ver la frecuencia de las palabras
def paso_diccionario_word_frecuencia (lista):
  dic = {}
  for word in lista:
    if word in dic.keys():
      dic[word] += 1
    else:
      dic[word] = 1
  return dic

#Funcion para eliminar strings como menos de tres caracteres
def saco_palabras_cortas (lista_tokens_frecuencia):
  for i, word in enumerate(lista_tokens_frecuencia):
    if (len(word[0]) < 3):
      lista_tokens_frecuencia.pop(i)
  return lista_tokens_frecuencia

#Funcion para appendear listas sin repetir
def sumo_listas (lista1, lista2):
  for elemento in lista1:
    if not elemento in lista2:
      lista2.append(elemento)
  return lista2

# %% [markdown]
# ## Limpieza Location

# %%
#Limpieza sobre el campo location
train['location'] = train.location.transform(lambda x: html.unescape(x))
train['location'] = train.location.transform(lambda x: urllib.parse.unquote(str(x)))
train['location'] = train.location.transform(lambda x: re.compile(r'<.*?>').sub(r'', x))
train['location'] = train.location.transform(lambda x: x.translate(str.maketrans('','',string.punctuation)))
train['location'] = train.location.transform(lambda x: x.lower())
train['location'] = train.location.transform(lambda x: x.translate(str.maketrans('','','1234567890')))
train['location'] = train.location.transform(lambda x: remuevo_caracteres_de_lista(x, caracteres_extraños))
train['location'] = train.location.transform(lambda x: remuevo_caracteres_de_lista(x, monosilabos))

# %%
#Encoding binario sobre Location
labelbinarizer = LabelBinarizer()
X_location = labelbinarizer.fit_transform(train.location)

# %%
np.shape(X_location)
# Out:
# (10876, 4134)

# %% [markdown]
# ## Limpieza Keyword

# %%
#Limpieza del campo keyword y encoding binario
train['keyword'] = train.keyword.transform(lambda x: urllib.parse.unquote(str(x)))
train['keyword'] = train.keyword.transform(lambda x: re.compile(r'<.*?>').sub(r'', x))
train['keyword'] = train.keyword.transform(lambda x: x.translate(str.maketrans('','',string.punctuation)))
train['keyword'] = train.keyword.transform(lambda x: x.lower())
train['keyword'] = train.keyword.transform(lambda x: x.translate(str.maketrans('','','1234567890')))
train['keyword'] = train.keyword.transform(lambda x: remuevo_caracteres_de_lista(x, caracteres_extraños))
train['keyword'] = train.keyword.transform(lambda x: remuevo_caracteres_de_lista(x, monosilabos))
labelbinarizer = LabelBinarizer()
X_keyword = labelbinarizer.fit_transform(train.keyword)

# %%
np.shape(X_keyword)
# Out:
# (10876, 222)

# %% [markdown]
# ## Limpieza Texto

# %%
train['text_len'] = train.text.transform(lambda x: len(clean_texto(x, caracteres_extraños, monosilabos)))

sns.set(font_scale = 1)
plt.figure(figsize = (8, 6))

plt.hist(train.text_len.values, bins = range(0, 200, 10))
plt.xlabel('Number of characteres')
plt.ylabel('Frecuency')
plt.show()

# %%
notes = list(train.text.values) #Creo una lista del campo text
#random.seed(42)
#random.shuffle(notes)
tokens = custom_tokenize(notes, caracteres_extraños, monosilabos) #Limpio y creo tokens
palabras_para_sacar = [word for word in tokens if len(word) < 3] #Elimino strings con menos de tres caracteres
words_to_clean = sumo_listas(palabras_para_sacar, words_to_clean) #Agrego palabras para sacar
#tokens = sorted(tokens)
#dic_tokens = paso_diccionario_word_frecuencia(tokens)
#lista_tokens_frecuencia = list(dic_tokens.items())
#lista_tokens_frecuencia_limpia = saco_palabras_cortas(lista_tokens_frecuencia)
#lista_tokens_frecuencia_limpia = saco_palabras_cortas(lista_tokens_frecuencia_limpia)

# %%
corpus = [clean_texto(texto, caracteres_extraños, monosilabos) for texto in notes] #Lista final limpia

# %%
#Creo los vectores para cada twit
vectorizer = CountVectorizer(analyzer = 'word', stop_words = words_to_clean, lowercase = True, strip_accents = 'ascii', ngram_range = (1, 1)) #(2, 2) bigrams
X_texto_vectorizer = vectorizer.fit_transform(corpus)
X_texto = X_texto_vectorizer.toarray()
np.shape(X_texto)
# Out:
# (10876, 20645)

# %% [markdown]
# # Modelo

# %%
X_franco = train[franco_features].values

# %%
X_text_len = labelbinarizer.fit_transform(train.text_len)
np.shape(X_text_len)
# Out:
# (10876, 141)

# %% [markdown]
# ### **PCA**

# %%
#del X_texto_vectorizer
#X_texto_norm = StandardScaler().fit_transform(X_texto) #Estandarizo la matriz para PCA. No influye en en un arbol
#pca = PCA(n_components = 8000)
#X_texto_red = pca.fit_transform(X_texto_norm)

# %%
#pca = PCA(n_components=2)
#principalComponents = pca.fit_transform(X_texto_norm)
#principalDf = pd.DataFrame(data = principalComponents, columns = ['c1', 'c2'])
#principalDf_train = principalDf.loc[0:7612, :]
#finalDf_train = pd.concat([principalDf_train, train_original.target], axis = 1)

# %%
#finalDf.head(1)

# %%
#f, ax = plt.subplots(figsize = (25, 50))
#sns.scatterplot(finalDf_train.c1, finalDf_train.c2, hue =  finalDf_train.target)

# %%
#principalDf_test = principalDf.loc[7613:, :]
#f, ax = plt.subplots(figsize = (25, 50))
#sns.scatterplot(finalDf_train.c1, finalDf_train.c2, hue =  finalDf_train.target)

# %% [markdown]
# ### **Split**

# %%
#Agrego o saco columnas al set de datos X
y = train.target.values
#X = X_texto_red
X = X_texto
X = np.hstack((X, X_keyword))
#X = np.hstack((X, X_text_len))
X = np.hstack((X, X_location))
#X = np.delete(X, 23235, axis = 1) #Le saco el location pionner....
X = np.hstack((X, X_franco))

# %%
#del X_texto_red

# %%
np.shape(y)
# Out:
# (10876,)

# %%
np.shape(X)
# Out:
# (10876, 27422)

# %%
#Separo entre fit y submit
X_fit = X[0:7613]
X_submit = X[7613:]
y_fit = y[0:7613]
y_submit = y[7613:]

# %%
#X_train, X_test, y_train, y_test = train_test_split(X_fit, y, test_size = 0.2, random_state = 123) #Con esto separo train y test
X_train = X_fit[0:6090]
X_test = X_fit[6090:]
y_train = y_fit[0:6090]
y_test = y_fit[6090:]
print(np.shape(X_train))
print(np.shape(X_test))
print(np.shape(y_train))
print(np.shape(y_test))
# Out:
# (6090, 27422)
# (1523, 27422)
# (6090,)
# (1523,)

# %%
#del X_fit

# %% [markdown]
# # Optimización Bayesiana

# %%
def bayes_parameter_opt_lgb(X_train, y_train, init_round = 15, opt_round = 25, n_folds = 1, random_seed = 0, n_estimators = 7155, output_process=False):
    
    # Preparo la data
    lgb_train = lgb.Dataset(X_train, y_train)
    
    # parameters
    def lgb_eval(learning_rate, num_leaves, min_split_gain, min_data_in_leaf, min_child_weight, max_depth, feature_fraction):
      
        params = {"objective" : "regression", "metric" : 'rmse'}
        params['learning_rate'] = learning_rate
        params['num_leaves'] = int(round(num_leaves))
        params['min_split_gain'] = min_split_gain
        params['min_data_in_leaf'] = int(round(min_data_in_leaf))
        params['min_child_weight'] = min_child_weight
        params['max_depth'] = int(round(max_depth))
        params['feature_fraction'] = max(min(feature_fraction, 1), 0)
         


        cv_result = lgb.cv(params, lgb_train, nfold=n_folds, seed = random_seed, stratified=False)
        return (-1.0 * np.array(cv_result['rmse-mean'])).max()
    
        # Defino rangos 
    lgbBO = BayesianOptimization(lgb_eval, {'learning_rate' : (0.1, 0.15),
                                            'num_leaves' : (100, 200),
                                            'min_split_gain' : (0.001, 0.1),
                                            'min_data_in_leaf' : (10, 30),
                                            'min_child_weight' : (5, 50),
                                            'max_depth' : (5, 9),
                                            'feature_fraction': (0.1, 0.9)}, random_state=0)

        # optimizo
    lgbBO.maximize(init_points = init_round, n_iter = opt_round, acq = 'ei')

        # Guardar los resultados
    if output_process == True: 
      lgbBO.points_to_csv("bayes_opt_result.csv")
      files.download('bayes_opt_result.csv')


        
    return lgbBO.res #['max']['max_params']

opt_params = bayes_parameter_opt_lgb(X_train, y_train, init_round = 10, opt_round = 15, n_folds = 7, n_estimators = 7155)
# Out:
# |   iter    |  target   | featur... | learni... | max_depth | min_ch... | min_da... | min_sp... | num_le... |
# -------------------------------------------------------------------------------------------------------------
# |  1        | -0.2045   |  0.5391   |  0.1358   |  7.411    |  29.52    |  18.47    |  0.06494  |  143.8    |
# |  2        | -0.1983   |  0.8134   |  0.1482   |  6.534    |  40.63    |  20.58    |  0.05724  |  192.6    |
# |  3        | -0.2292   |  0.1568   |  0.1044   |  5.081    |  42.47    |  25.56    |  0.08713  |  197.9    |
# |  4        | -0.2009   |  0.7393   |  0.1231   |  8.122    |  10.32    |  22.8     |  0.01519  |  194.5    |
# |  5        | -0.2002   |  0.5175   |  0.1207   |  6.058    |  39.84    |  19.12    |  0.05727  |  101.9    |
# |  6        | -0.1989   |  0.5941   |  0.1306   |  7.468    |  47.47    |  23.64    |  0.03659  |  143.7    |
# |  7        | -0.199    |  0.6581   |  0.103    |  7.667    |  35.18    |  14.21    |  0.01376  |  131.5    |
# |  8        | -0.2028   |  0.391    |  0.1285   |  6.754    |  49.48    |  12.04    |  0.02168  |  116.1    |
# |  9        | -0.2025   |  0.6225   |  0.1127   |  6.865    |  16.0     |  13.18    |  0.01193  |  165.6    |
# |  10       | -0.2118   |  0.2105   |  0.1098   |  6.475    |  41.94    |  11.94    |  0.08396  |  109.6    |
# |  11       | -0.1993   |  0.7731   |  0.1349   |  8.428    |  27.45    |  10.06    |  0.05969  |  198.6    |
# |  12       | -0.2056   |  0.5164   |  0.1421   |  8.014    |  7.395    |  29.63    |  0.04265  |  102.0    |
# |  13       | -0.2004   |  0.9      |  0.15     |  9.0      |  49.99    |  10.0     |  0.001    |  183.1    |
# |  14       | -0.2033   |  0.5833   |  0.1214   |  9.0      |  47.1     |  27.96    |  0.003239 |  101.3    |
# |  15       | -0.1976   |  0.8477   |  0.1462   |  5.283    |  32.93    |  15.67    |  0.09751  |  177.3    |
# |  16       | -0.2008   |  0.7596   |  0.1231   |  7.181    |  16.02    |  13.46    |  0.05021  |  165.5    |
# |  17       | -0.1998   |  0.7957   |  0.1259   |  8.995    |  30.12    |  21.6     |  0.09543  |  188.8    |
# |  18       | -0.1977   |  0.855    |  0.135    |  5.073    |  47.84    |  28.12    |  0.06954  |  115.1    |
# |  19       | -0.2038   |  0.8725   |  0.1015   |  7.941    |  5.102    |  11.13    |  0.06673  |  194.9    |
# |  20       | -0.1972   |  0.8583   |  0.1135   |  5.423    |  5.131    |  23.7     |  0.0291   |  167.1    |
# |  21       | -0.1987   |  0.8962   |  0.1016   |  6.731    |  49.17    |  14.48    |  0.0491   |  137.0    |
# |  22       | -0.1996   |  0.8772   |  0.1396   |  8.505    |  48.63    |  22.25    |  0.0703   |  128.4    |
# |  23       | -0.1968   |  0.7199   |  0.1194   |  5.105    |  5.991    |  10.08    |  0.03495  |  129.9    |
# |  24       | -0.1966   |  0.7725   |  0.1212   |  5.07     |  6.139    |  16.97    |  0.06783  |  100.1    |
# |  25       | -0.1978   |  0.8379   |  0.1138   |  6.491    |  49.86    |  21.01    |  0.05909  |  102.4    |
# =============================================================================================================

# %%
i = 23
params = opt_params[i]['params']
params['max_depth'] = int(round(opt_params[i]['params']['max_depth'], 0))
params['num_leaves'] = int(round(opt_params[i]['params']['num_leaves'], 0))
params['min_data_in_leaf'] = int(round(opt_params[i]['params']['min_data_in_leaf'], 0))
params['objective'] = 'regression'
params['metric'] = 'rmse'
params['n_estimators'] = 7155
params['feature_fraction'] = 1
#params['bagging_freq'] = 5
#params['max_bin'] = 409
#params['min_child_samples'] = 10
#params['num_iteraciones'] = 100
params
# Out:
# {'feature_fraction': 1,
#  'learning_rate': 0.12115883933485813,
#  'max_depth': 5,
#  'metric': 'rmse',
#  'min_child_weight': 6.139293499274847,
#  'min_data_in_leaf': 17,
#  'min_split_gain': 0.06782820575864967,
#  'n_estimators': 7155,
#  'num_leaves': 100,
#  'objective': 'regression'}

# %% [markdown]
# # LGBM

# %%
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_test, y_test, reference = lgb_train)

gbm = lgb.train(params,
                lgb_train,
                num_boost_round = 120,
                valid_sets = lgb_eval,
                early_stopping_rounds = 1000)

preds = gbm.predict(X_test, num_iteration=gbm.best_iteration)
rmse = np.sqrt(mean_squared_error(y_test, preds))
preds_class = np.where(preds > 0.5, 1, 0)
score = f1_score(y_test, preds_class)

print("RMSE: %f" % (rmse))
print("F1_SCORE: %f" % (score))
# Out:
# [1]	valid_0's rmse: 0.47906
# Training until validation scores don't improve for 1000 rounds.
# [2]	valid_0's rmse: 0.467981
# [3]	valid_0's rmse: 0.458531
# [4]	valid_0's rmse: 0.452383
# [5]	valid_0's rmse: 0.449213
# [6]	valid_0's rmse: 0.445917
# [7]	valid_0's rmse: 0.442514
# [8]	valid_0's rmse: 0.440034
# [9]	valid_0's rmse: 0.439778
# [10]	valid_0's rmse: 0.437507
# [11]	valid_0's rmse: 0.438538
# [12]	valid_0's rmse: 0.437229
# [13]	valid_0's rmse: 0.436987
# [14]	valid_0's rmse: 0.436528
# [15]	valid_0's rmse: 0.435921
# [16]	valid_0's rmse: 0.435491
# [17]	valid_0's rmse: 0.435204
# [18]	valid_0's rmse: 0.435839
# [19]	valid_0's rmse: 0.435812
# [20]	valid_0's rmse: 0.435694
# [21]	valid_0's rmse: 0.43566
# [22]	valid_0's rmse: 0.435558
# [23]	valid_0's rmse: 0.435615
# [24]	valid_0's rmse: 0.435415
# [25]	valid_0's rmse: 0.436038
# [26]	valid_0's rmse: 0.435939
# [27]	valid_0's rmse: 0.435918
# [28]	valid_0's rmse: 0.436398
# [29]	valid_0's rmse: 0.436468
# [30]	valid_0's rmse: 0.436724
# [31]	valid_0's rmse: 0.436664
# [32]	valid_0's rmse: 0.436737
# [33]	valid_0's rmse: 0.437029
# [34]	valid_0's rmse: 0.436995
# [35]	valid_0's rmse: 0.437175
# [36]	valid_0's rmse: 0.437192
# [37]	valid_0's rmse: 0.437234
# [38]	valid_0's rmse: 0.437324
# [39]	valid_0's rmse: 0.437388
# [40]	valid_0's rmse: 0.43744
# [41]	valid_0's rmse: 0.437396
# [42]	valid_0's rmse: 0.437358
# [43]	valid_0's rmse: 0.437449
# [44]	valid_0's rmse: 0.437375
# [45]	valid_0's rmse: 0.437318
# [46]	valid_0's rmse: 0.43734
# [47]	valid_0's rmse: 0.437276
# [48]	valid_0's rmse: 0.437209
# [49]	valid_0's rmse: 0.437144
# [50]	valid_0's rmse: 0.437243
# [51]	valid_0's rmse: 0.437174
# [990]	valid_0's rmse: 0.43674
# [991]	valid_0's rmse: 0.43674
# [992]	valid_0's rmse: 0.43674
# [993]	valid_0's rmse: 0.43674
# [994]	valid_0's rmse: 0.43674
# [995]	valid_0's rmse: 0.43674
# [996]	valid_0's rmse: 0.43674
# [997]	valid_0's rmse: 0.43674
# [998]	valid_0's rmse: 0.43674
# [999]	valid_0's rmse: 0.43674
# [1000]	valid_0's rmse: 0.43674
# [1001]	valid_0's rmse: 0.43674
# [1002]	valid_0's rmse: 0.43674
# [1003]	valid_0's rmse: 0.43674
# [1004]	valid_0's rmse: 0.43674
# [1005]	valid_0's rmse: 0.43674
# [1006]	valid_0's rmse: 0.43674
# [1007]	valid_0's rmse: 0.43674
# [1008]	valid_0's rmse: 0.43674
# [1009]	valid_0's rmse: 0.43674
# [1010]	valid_0's rmse: 0.43674
# [1011]	valid_0's rmse: 0.43674
# [1012]	valid_0's rmse: 0.43674
# [1013]	valid_0's rmse: 0.43674
# [1014]	valid_0's rmse: 0.43674
# [1015]	valid_0's rmse: 0.43674
# [1016]	valid_0's rmse: 0.43674
# [1017]	valid_0's rmse: 0.43674
# Early stopping, best iteration is:
# [17]	valid_0's rmse: 0.435204
# RMSE: 0.435204
# F1_SCORE: 0.632826

# %%
sns.set(font_scale = 1)
plt.figure(figsize = (25, 30))
lgb.plot_importance(gbm,  max_num_features = 20, title = "Palabras más influyentes")

# %%
print(vectorizer.get_feature_names()[2454])
print(vectorizer.get_feature_names()[6577])
print(vectorizer.get_feature_names()[6679])
print(vectorizer.get_feature_names()[9842])
print(vectorizer.get_feature_names()[9976])
print(vectorizer.get_feature_names()[2776])
print(vectorizer.get_feature_names()[19842])
print(vectorizer.get_feature_names()[9])
print(vectorizer.get_feature_names()[4])
print(vectorizer.get_feature_names()[2676])
print(vectorizer.get_feature_names()[16698])
print(vectorizer.get_feature_names()[4030])
# Out:
# buildings
# fires
# floods
# kick
# know
# car
# weapon
# aar
# aaceorg
# camilas
# smithsonianno
# crash

# %%
features = np.hstack((vectorizer.get_feature_names(), train.keyword.unique()))
#features = np.hstack((features, train.columns[5]))
features = np.hstack((features, train.location.unique()))
features = np.hstack((features, franco_features))
len(features) - len(gbm.feature_importance())
# Out:
# 0

# %%
feature_imp = pd.DataFrame({'Value': gbm.feature_importance(), 'Feature': features})
plt.figure(figsize = (40, 20))
sns.set(font_scale = 5)
sns.barplot(x = "Value", y = "Feature", data = feature_imp.sort_values(by = "Value", ascending = False)[0:25])
plt.title('Palabras más influyentes')
plt.tight_layout()
#plt.savefig('lgbm_importances-01.png')
plt.show()

# %%
preds_submit = gbm.predict(X_submit, num_iteration=gbm.best_iteration)
resultados = pd.DataFrame(data = preds_submit, columns = ['target'])
resultados.insert(0, 'id', set_submit_franco.id)
resultados['target'] = resultados.target.transform(lambda x: 1 if x > 0.5 else 0)

# %%
resultados.head()
# Out:
#    id  target
# 0   0       1
# 1   2       1
# 2   3       0
# 3   9       0
# 4  11       0

# %%
resultados.to_csv('submission_12_LGBM.csv', header = True, index = False) 
files.download('submission_12_LGBM.csv')

# %%
lgb.create_tree_digraph(gbm)
